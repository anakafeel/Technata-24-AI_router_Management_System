# %% [markdown]
# <a href="https://colab.research.google.com/github/anakafeel/Technata-24-AI_router_Management_System/blob/main/AI_Router_Management_Systeml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Model - Training**

# %% [markdown]
# # reading the csv

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/anakafeel/Technata-24-AI_router_Management_System/refs/heads/main/simulated_router_data.csv?token=GHSAT0AAAAAACWNR4NZDSJHWIIU66IPLX5KZXXL24Q')
df
# Out:
#                   DateTime  RouterID  FlowBytes           ID  \
# 0      2015-11-01 00:00:00         1         15  20151101001
# 1      2015-11-01 01:00:00         1         13  20151101011
# 2      2015-11-01 02:00:00         1         10  20151101021
# 3      2015-11-01 03:00:00         1          7  20151101031
# 4      2015-11-01 04:00:00         1          9  20151101041
# ...                    ...       ...        ...          ...
# 48115  2017-06-30 19:00:00         4         11  20170630194
# 48116  2017-06-30 20:00:00         4         30  20170630204
# 48117  2017-06-30 21:00:00         4         16  20170630214
# 48118  2017-06-30 22:00:00         4         22  20170630224
# 48119  2017-06-30 23:00:00         4         12  20170630234
#
#        EnergyConsumptionW  HeatDissipationBTU  EnergySavingMode
# 0                  784.30          2676.03160                 1
# 1                  784.26          2675.89512                 1
# ...

# %% [markdown]
# # time seperation

# %% [markdown]
# #**Data-Seperation**

# %%
y = df['EnergySavingMode']
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 48115    1
# 48116    0
# 48117    1
# 48118    0
# 48119    1
# Name: EnergySavingMode, Length: 48120, dtype: int64

# %%
X = df.drop('EnergySavingMode', axis=1)
X
# Out:
#                   DateTime  RouterID  FlowBytes           ID  \
# 0      2015-11-01 00:00:00         1         15  20151101001
# 1      2015-11-01 01:00:00         1         13  20151101011
# 2      2015-11-01 02:00:00         1         10  20151101021
# 3      2015-11-01 03:00:00         1          7  20151101031
# 4      2015-11-01 04:00:00         1          9  20151101041
# ...                    ...       ...        ...          ...
# 48115  2017-06-30 19:00:00         4         11  20170630194
# 48116  2017-06-30 20:00:00         4         30  20170630204
# 48117  2017-06-30 21:00:00         4         16  20170630214
# 48118  2017-06-30 22:00:00         4         22  20170630224
# 48119  2017-06-30 23:00:00         4         12  20170630234
#
#        EnergyConsumptionW  HeatDissipationBTU
# 0                  784.30          2676.03160
# 1                  784.26          2675.89512
# 2                  784.20          2675.69040
# ...

# %%
if 'DateTime' in X.columns:
    X['DateTime'] = pd.to_datetime(X['DateTime'])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)


X_train
# Out:
#                  DateTime  RouterID  FlowBytes           ID  \
# 22777 2016-10-07 01:00:00         2         16  20161007012
# 38344 2016-11-16 16:00:00         3         19  20161116163
# 36448 2016-08-29 16:00:00         3         22  20160829163
# 26383 2017-03-06 07:00:00         2         13  20170306072
# 2948  2016-03-02 20:00:00         1         44  20160302201
# ...                   ...       ...        ...          ...
# 16304 2016-01-11 08:00:00         2          4  20160111082
# 79    2015-11-04 07:00:00         1         11  20151104071
# 12119 2017-03-19 23:00:00         1         62  20170319231
# 14147 2017-06-12 11:00:00         1        117  20170612111
# 38408 2016-11-19 08:00:00         3          9  20161119083
#
#        EnergyConsumptionW  HeatDissipationBTU
# 22777              784.32          2676.09984
# 38344              784.38          2676.30456
# 36448              784.44          2676.50928
# 26383              784.26          2675.89512
# ...

# %%
if 'DateTime' in X_train.columns:
    X_train['year'] = X_train['DateTime'].dt.year
    X_train['month'] = X_train['DateTime'].dt.month
    X_train['day'] = X_train['DateTime'].dt.day
    X_train['hour'] = X_train['DateTime'].dt.hour

X_train
# Out:
#        RouterID  FlowBytes           ID  EnergyConsumptionW  \
# 22777         2         16  20161007012              784.32
# 38344         3         19  20161116163              784.38
# 36448         3         22  20160829163              784.44
# 26383         2         13  20170306072              784.26
# 2948          1         44  20160302201              784.88
# ...         ...        ...          ...                 ...
# 16304         2          4  20160111082              784.08
# 79            1         11  20151104071              784.22
# 12119         1         62  20170319231              785.24
# 14147         1        117  20170612111              786.34
# 38408         3          9  20161119083              784.18
#
#        HeatDissipationBTU  year  month  day  hour
# 22777          2676.09984  2016     10    7     1
# 38344          2676.30456  2016     11   16    16
# 36448          2676.50928  2016      8   29    16
# ...

# %%
X_test
# Out:
#                   DateTime  RouterID  FlowBytes           ID  \
# 19941  2016-06-10 21:00:00         2         10  20160610212
# 5958   2016-07-06 06:00:00         1         18  20160706061
# 34963  2016-06-28 19:00:00         3          9  20160628193
# 5672   2016-06-24 08:00:00         1         27  20160624081
# 25425  2017-01-25 09:00:00         2         12  20170125092
# ...                    ...       ...        ...          ...
# 3683   2016-04-02 11:00:00         1         25  20160402111
# 10191  2016-12-29 15:00:00         1         71  20161229151
# 34146  2016-05-25 18:00:00         3          9  20160525183
# 47624  2017-06-10 08:00:00         4          3  20170610084
# 21656  2016-08-21 08:00:00         2          4  20160821082
#
#        EnergyConsumptionW  HeatDissipationBTU
# 19941              784.20          2675.69040
# 5958               784.36          2676.23632
# 34963              784.18          2675.62216
# ...

# %% [markdown]
# #**MODEL-BUILDING**

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)

LinearRegression()
# Out:
# LinearRegression()
